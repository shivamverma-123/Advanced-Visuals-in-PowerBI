# %% [markdown]
# #Advanced Visuals in PowerBI
#
# Q1.What is the difference between a Basic Filter, Advanced Filter, and a Slicer in Power BI?
#
# Ans: The difference between a basic filter,advance filter and a slicer in power bi are
# | Type                | Meaning                            | Example                  |
# | ------------------- | ---------------------------------- | ------------------------ |
# | **Basic Filter**    | Simple selection (checkbox list)   | Year = 2023 select karna |
# | **Advanced Filter** | Condition based filtering          | Sales > 50000            |
# | **Slicer**          | Visual filter (interactive button) | Region slicer add karna  |
#
#
# Q2.Using the Sales dataset, apply a Basic Filter to display only the sales data for the year 2023.
#
# Ans:To show the sales data sets using basic filter to dispaly are
#
# Steps:
#
# 1.Filters pane open karo
#
# 2.Year field ko drag karo
#
# 3.Basic Filtering select karo
#
# 4.2023 tick karo
#
# Q3.Create a Pie Chart of Sales by Product and add Slicer that allows users to filter the dataset by Region.
#
# Ans:To create a pie chart of sales by product and add slicers that allows user to filter the dataset by region are
#
# Steps:
#
# 1.Pie Chart add karo
#
# 2.Values → Sales
#
# 3.Legend → Product
#
# 4.Slicer add karo
#
# 5.Field → Region.
#
# Q4.What is a Visual-Level Filter, and how does it differ from Page-Level and Report-Level Filters?
#
# Ans:To the types of visuals-level filter and how does it differ from page-level and report-level filters are
#
# | Filter Type      | Effect                            |
# | ---------------- | --------------------------------- |
# | **Visual-Level** | Sirf ek visual par apply hota hai |
# | **Page-Level**   | Puri page ke sab visuals par      |
# | **Report-Level** | Puri report ke sab pages par      |
#
# Q5.Apply a Report-Level Filter so that all visuals in the Power BI report display sales only from India?
#
# Ans:To a report level filter so that all visuals in the power bi report display are
#
# 1.Filters pane me Report-Level Filters section
#
# 2.Country field drag karo
#
# 3.India select karo
#
# Q6.What is the role of Drill-Down in Power BI? How does it improve data exploration?
#
# Ans: Drill-Down se hum summary se detailed level tak ja sakte hain.
#
# Example:
# Year → Quarter → Month → Day.
#
# Q7.Using the dataset, create a hierarchy drill-down from
#  Country → Region → Product Category to analyze sales at different levels.
#
# Ans:To use the datasets create a hierarchy drill-down from country region product category to analyze are as follow as
#
# Steps:
#
# 1.Right click Country → Create Hierarchy
#
# 2.Add Region
#
# 3.Add Product Category
#
# 4.Is hierarchy ko chart me use karo
#
# 5.Drill-down button enable karo
#
# Q8.Implement Drill-Through so that selecting a Product navigates to a detailed report page showing regionwise sales.
#
# Ans:To drill implemented through so that selecting a product navigates to a detailed report page showing regionwise sales are
#
# Steps:
#
# 1.New page create karo
#
# 2.Drill-through section me Product field drag karo
#
# 3.Region-wise Sales chart add karo.
#
# Q9.Add a Slicer for Product Category and observe how it interacts with the drill-down hierarchy.
#
# Ans: We have to add a slicer for product category and observe how it interacts with the drill down hierarchy are
#
# Step
# 1.Slicer add karo
#
# 2.Field → Product Category
#
# 3.Drill hierarchy chart ke sath interact karega.
#
# Q10.Explain the difference between Drill-Down and Drill-Through in Power BI using a real-world example
#
# Ans:To explain the difference between drill-down and drill through in power bi using real world example are
#
# | Drill-Down                  | Drill-Through                        |
# | --------------------------- | ------------------------------------ |
# | Same visual me level change | New page open hota hai               |
# | Example: Year → Month       | Example: Product click → Detail page |
#
# Q11.Down feature to analyze sales trends from
#  Year → Quarter → Month → Day?
#
# Ans:We have down features to analyze sales trends from year-quarter-month-day are
#
# 1.Date field use karo
#
# 2.Line Chart me drag karo
#
# 3.Drill mode enable karo.
#
# Q12.Apply a Measure-Based Filter to display only those products where total sales exceed ₹50,000.
# (Hint: Create a Total Sales measure and apply the filter using the measure, not the Sales column).
#
# Ans:To apply measure based filter to display only those products where total sales exceed rs50,000 are
#
#     Total Sales = SUM(Sales_dataset[Sales])
#
# Now:
#
# 1.Filters pane me Total Sales drag karo
#
# 2.Advanced filtering
#
# 3.is greater than 50000
#
# Q13.What is the “Keep All Filters” option in Drill-Through? How does it affect user interaction?
#
# Ans:To keep all the filters option in drill through how does it affect user interaction are
#
# Agar ON hai:
#
#  Previous page ke slicer filters bhi apply rahenge.
#
# Agar OFF hai:
#
# Sirf selected field ka filter apply hoga.
#
# Q14.Create a custom Drill-Through page where selecting a Region shows a detailed view of sales trends over
# time
#
# Ans:To create a custom drill through pages where selecting a region shows a detailed view of sales trends over time are
#
# 1.New page create karo
#
# 2.Drill-through me Region drag karo
#
# 3.Line chart add karo
#
# 4.Axis → Date
#
# 5.Values → Sales
#
# Right click Region → Drill-through.
#
# Q15.Design a fully interactive Power BI dashboard using Slicers, Filters, Drill-Down, and Drill-Through to explore
# sales data?
#
# Ans:We have to design the fully interactive power bi dashboards using slicers ,filters, drill and many more
#
# Dashboard me include karo:
#
# 1.KPI Card (Total Sales)
#
# 2.Pie Chart (Product-wise Sales)
#
# 3.Line Chart (Time Trend)
#
# 4.Bar Chart (Region-wise Sales)
#
# 5.Slicers (Region, Product Category, Year)
#
# 6.Drill-Down hierarchy
#
# 7.Drill-Through detail page
